# %%
import numpy as np
import os
import pandas as pd
from Parser import Parameters
from lammps import lammps

# %%
L = lammps()
print(L.version())
print(L.has_package("EXTRA-FIX"))
# Out:
# LAMMPS (28 Mar 2023 - Development)
# OMP_NUM_THREADS environment is not set. Defaulting to 1 thread. (src/comm.cpp:98)
#   using 1 OpenMP thread(s) per MPI task
# Total wall time: 0:02:55
# 20230328
# True

# %%
cmds = """ArithmeticError
asdf
asdf
"""
print(cmds.splitlines())
# Out:
# ['ArithmeticError', 'asdf', 'asdf']

# %%
np.issubdtype(np.zeros(3).dtype,float)
# Out:
# True

# %%
l = [np.random.uniform(size=(30,3)),np.random.uniform(size=(30,3)),np.random.uniform(size=(30,3)),np.random.uniform(size=(30,3)),np.random.uniform(size=(30,3))]
print(np.array(l).shape)
print(np.einsum('ijk->jki',np.array(l)).shape)
# Out:
# (5, 30, 3)
# (30, 3, 5)

# %%
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline
