# %%
import pandas as pd

# %%
pd.read_csv("dumps/pafi_data_3.csv")
# Out:
#     Unnamed: 0  Temperature  ReactionCoordinate  SampleSteps  ThermSteps  \
# 0            0          0.0                 0.0           50          10
# 1            1          0.0                 0.0           50          10
# 2            2          0.0                 0.0           50          10
# 3            3          0.0                 0.0           50          10
# 4            4          0.0                 0.5           50          10
# 5            5          0.0                 0.5           50          10
# 6            6          0.0                 0.5           50          10
# 7            7          0.0                 0.5           50          10
# 8            8          0.0                 1.0           50          10
# 9            9          0.0                 1.0           50          10
# 10          10          0.0                 1.0           50          10
# 11          11          0.0                 1.0           50          10
#
# ...
